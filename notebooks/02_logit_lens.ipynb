# %% [markdown]
# # Logit lens: single-prompt trace
#
# Correlational only — see `src/logit_lens.py` module docstring.

# %%
import sys
sys.path.insert(0, '..')
from src.model import load_model
from src.hooks import run_with_cache
from src.logit_lens import build_trace

model = load_model('gemma-2-2b')
prompt = 'හිරු ඔදා වැටෙන්නේ'  # 'The sun rises in the ___'
tokens, logits, cache = run_with_cache(model, prompt)
trace = build_trace(model, prompt, cache)
